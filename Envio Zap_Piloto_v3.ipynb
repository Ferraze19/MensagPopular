# %%
import pyautogui
import pyperclip
import time
import import_ipynb
import Base_Dados as bd
import Open_edge
# Out:
# importing Jupyter notebook from Base_Dados.ipynb
# importing Jupyter notebook from Open_edge.ipynb

# %%
def Enviar(lista_contatos):
    time.sleep(3)
    #for i in  [0]:
    for i in lista_contatos.index:
        Numero = str(lista_contatos.at[i, "Celular:"]) #Obter iésima entrada de dado de número de celular
        Nome = str(lista_contatos.at[i, "Nome:"])
        Link = f"https://web.whatsapp.com/send?phone=+{Numero[0:13]}"
        pyautogui.hotkey("Alt", "d")
        time.sleep(0.5)
        #pyautogui.hotkey("Ctrl", "A")
        pyperclip.copy(Link)
        time.sleep(0.5)
        pyautogui.hotkey("Ctrl", "V")
        time.sleep(0.5)
        pyautogui.press('Enter')
        time.sleep(8)
        pyautogui.click(x=1083, y=697)
        pyperclip.copy(f"""Olá {Nome}!
        
        💰💰CONTRIBUA COM SEU PARTIDO💰💰
        
        A Unidade Popular pelo Socialismo é um partido do povo pobre e que tem a independência política necessária para enfrentar os donos do poder em nosso país.
        
        Mas precisamos garantir nossa independência financeira, quem paga a banda escolhe a música.
        
        Por isso defendemos a autossustentação como política de finanças e cada contribuição por menor que seja é muito valiosa.
        
        Camarada do ESTADO do *RJ* contribua com seu partido!
        
        Banco: Banco do Brasil
        AG: 392-1
        CC: 60877-7
        CNPJ:  38.906.009/0001-39 (PIX)""")
        time.sleep(0.5)
        pyautogui.hotkey("Ctrl", "V")
        time.sleep(1)
        pyautogui.press('Enter')
        time.sleep(0.5)
        print(Nome)
        #input()

# %%
#Enviar mensagem para todos os contatos da lista
lista_contatos = bd.Format_Numb(bd.Criar_lista_contatos())
Open_edge.Open_edge()
Enviar(lista_contatos)
# Out:
# Jocivan Santos
# Kai Uchoa
# Laura Silva
# Luciana Lucas dos Santos Gomes
# Lucineide Bispo dos Santos
# Mariana Olimpio de Abreu
# Renan Belo
# Ricardo Santina Marins da Silva
# Robson Borges Gomes
# Andreza Freitas Ferreira
# Vagner Luiz Lopes de Sá junior
# Yan César
# Raphael Bittencourt Marinho
# Lívia Marques Sarmento
# Gabriel Pires Makluf
# Douglas Oliveira
# Luan Santos
# Maitê do Couto Oliva Costa
# Matheus Grama
# Alexsandro de Souza Tupinambá Tupinambá
# Maria Aguiar Vilhena de Carvalho
# Lucas Ledo Alves da Cunha Rocha
# Paulo Roberto
# Bruna de Moraes Costa
# João Pedro Nunes Pereira
# Igor Soldi
# Ana Carolina Peçanha
# João Gabriel
# Jorge Flávio Peçanha
# Lucio Amorim
# Pablito Torres
# Pierre Monteiro
# Larissa Dalcero
# Iago da Silva Felix
# Guilherme Salgado
# Frederick Marconni Mantuano Lopes da Silva
# Antônio kopanakis costa
# George Barbosa Sousa do Nascimento
# Bernardo Ferreira Dinucci
# Ana Luíza Barbosa Feitosa
# Marcela Werneck de Toste Fonseca
# ...

# %%
pyautogui.position()

# %%
Open_edge.Open_edge()

# %%
#Enviar mensagem para todos os filiados da lista
lista_filiados = bd.Criar_lista_filiados()
Open_edge.Open_edge()
Enviar(lista_filiados)
# Out:
# Adryanne Mendes
# Afro Frazão Nery (nome social)
# Alexandre Borges Batistella
# Alexandre dos Santos Padilha Bonifácio
# Alexandre dos Santos Verçosa
# Alexia Victória Chaves da Silva
# Alice Gonçalves Santos
# Alice Ribeiro de Rezende
# ALLAN MATHEUS SOARES DA SILVA
# Allan Rodrigues Ramos
# Allyce Gabriele Gonçalves
# Amanda Franciny Chagas Serafim
# Amaro Sergio da Silva Azevedo
# Ana Alice Oliveira da Rocha
# Ana Beatriz Araujo da Silva
# Ana Beatriz Kozlowsky Ortega
# Ana Beatriz Lopes Cherém
# Ana Carolina Miceli
# ANA CAROLINA OLIVEIRA MATTOS
# Ana Clara Pimentel Nicodemos
# Ana Karine de Sousa Dantas
# Ana Luisa Aragon Almeida
# Ana Luiza Barbosa Feitosa
# Ana Luíza Mendes de Brito Siqueira
# Ana Maria Auler Matheus Peres
# Ana Paula da Silva
# Ana Paula fediczko
# Ana Priscila Rezende de Carvalho
# Anderson Garcia da Cruz
# ANDRE PARKINSON MOREIRA JUNIOR
# André Preuss Araujo
# Andrei Alves de Souza
# Andressa Evaristo Paquiele da Silva
# Andressa Oliveira da Cruz
# ...
